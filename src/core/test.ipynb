# %% [markdown]
# # Testing AL

# %%
# !pip install -r requirements.txt

# %%
import al
import sklearn.datasets

# %%
X, y = sklearn.datasets.make_classification(n_samples=500)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
m = al.AL()

# %%
m.fit(X_train, y_train)
progs = m.get_programs()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Generating transforms
# Programs of depth=0
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 42.56it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 33.02it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 29.60it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 29.09it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:00<00:00, 25.27it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  92%|█████████▏| 24/26 [00:00<00:00, 29.12it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 1/1 [00:00<00:00,  1.11it/s]s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# [Transforms] Pruning programs of depth 0
# Programs of depth=1
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 47.51it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:00, 35.99it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 34.92it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 32.75it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 28.27it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:00<00:00, 29.64it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  10%|█         | 1/10 [00:00<00:07,  1.16it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 49.77it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  35%|███▍      | 9/26 [00:00<00:00, 38.06it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 36.40it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 33.81it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 29.61it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:00<00:00, 30.92it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  20%|██        | 2/10 [00:01<00:06,  1.18it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 44.98it/s]Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): None
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 40.23it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 39.02it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:00<00:00, 36.80it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:00<00:00, 35.30it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  30%|███       | 3/10 [00:02<00:05,  1.25it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 42.19it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 32.56it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 34.97it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 32.44it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 28.70it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:00<00:00, 30.04it/s]Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  40%|████      | 4/10 [00:03<00:04,  1.23it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 43.16it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 32.79it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): None
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 35.28it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 33.70it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 29.45it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  92%|█████████▏| 24/26 [00:00<00:00, 31.72it/s]Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  50%|█████     | 5/10 [00:04<00:04,  1.22it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 46.03it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 46.17it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  50%|█████     | 13/26 [00:00<00:00, 38.19it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 34.19it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 29.87it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
#  96%|█████████▌| 25/26 [00:00<00:00, 33.19it/s]
#  60%|██████    | 6/10 [00:04<00:03,  1.22it/s]]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 44.91it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 43.33it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  54%|█████▍    | 14/26 [00:00<00:00, 37.49it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  65%|██████▌   | 17/26 [00:00<00:00, 33.95it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  77%|███████▋  | 20/26 [00:00<00:00, 29.74it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:00<00:00, 33.12it/s]
#  70%|███████   | 7/10 [00:05<00:02,  1.22it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]
# Failed computing missing
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  15%|█▌        | 4/26 [00:00<00:00, 32.98it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.imputation.Imputer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  23%|██▎       | 6/26 [00:00<00:00, 25.27it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.pca.PCA): None
# Failed to apply transform(sklearn.decomposition.pca.PCA): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  38%|███▊      | 10/26 [00:00<00:00, 28.58it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 31.64it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): None
# Failed to apply transform(sklearn.preprocessing.data.PolynomialFeatures): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:00<00:00, 31.20it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): None
# Failed to apply transform(sklearn.preprocessing.data.MinMaxScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  81%|████████  | 21/26 [00:00<00:00, 27.88it/s]Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 26/26 [00:00<00:00, 30.18it/s]
#  80%|████████  | 8/10 [00:06<00:01,  1.21it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 43.63it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 33.49it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 32.31it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  62%|██████▏   | 16/26 [00:00<00:00, 31.28it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 27.68it/s]Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 26/26 [00:00<00:00, 32.39it/s]
#  90%|█████████ | 9/10 [00:07<00:00,  1.20it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  19%|█▉        | 5/26 [00:00<00:00, 43.98it/s]Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  31%|███       | 8/26 [00:00<00:00, 34.69it/s]Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  46%|████▌     | 12/26 [00:00<00:00, 33.33it/s]Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 32.29it/s]Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  69%|██████▉   | 18/26 [00:00<00:00, 27.21it/s]Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): None
# Failed to apply transform(sklearn.feature_selection.variance_threshold.VarianceThreshold): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  96%|█████████▌| 25/26 [00:00<00:00, 32.61it/s]Failed to apply transform(sklearn.preprocessing.label.LabelEncoder): None
#
# 100%|██████████| 10/10 [00:08<00:00,  1.20it/s]
#   0%|          | 0/10 [00:00<?, ?it/s]
#   0%|          | 0/26 [00:00<?, ?it/s]Failed to apply transform(sklearn.preprocessing.data.StandardScaler): None
# Failed to apply transform(sklearn.preprocessing.data.StandardScaler): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.module): None
# Failed to apply transform(builtins.module): <class 'synthesis.runtime_helpers.ColumnLoop'>
# [Transforms] Pruning programs of depth 1
# Programs of depth=2
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.CountVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.pipeline.Pipeline): None
# Failed to apply transform(sklearn.pipeline.Pipeline): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.dict_vectorizer.DictVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): None
# Failed to apply transform(sklearn.feature_selection.from_model.SelectFromModel): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  27%|██▋       | 7/26 [00:00<00:00, 50.53it/s]Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# ...
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): None
# Failed to apply transform(sklearn.decomposition.truncated_svd.TruncatedSVD): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): None
# Failed to apply transform(sklearn.ensemble.forest.RandomForestRegressor): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): None
# Failed to apply transform(sklearn.feature_extraction.text.TfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  42%|████▏     | 11/26 [00:00<00:00, 51.36it/s]Failed to apply transform(builtins.super): None
# Failed to apply transform(builtins.super): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.feature_extraction.text.TfidfTransformer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  58%|█████▊    | 15/26 [00:00<00:00, 43.95it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectFpr): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.svm.classes.LinearSVC): None
# Failed to apply transform(sklearn.svm.classes.LinearSVC): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): None
# Failed to apply transform(sklearn.datasets.samples_generator.make_regression): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  73%|███████▎  | 19/26 [00:00<00:00, 41.78it/s]Failed to apply transform(sklearn.datasets.base.load_boston): None
# Failed to apply transform(sklearn.datasets.base.load_boston): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): None
# Failed to apply transform(sklearn.tree.tree.DecisionTreeClassifier): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(builtins.StemmedTfidfVectorizer): None
# Failed to apply transform(builtins.StemmedTfidfVectorizer): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
#  88%|████████▊ | 23/26 [00:00<00:00, 41.10it/s]Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): None
# Failed to apply transform(sklearn.feature_selection.univariate_selection.SelectKBest): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.cross_validation.train_test_split): None
# Failed to apply transform(sklearn.cross_validation.train_test_split): <class 'synthesis.runtime_helpers.ColumnLoop'>
# Failed to apply transform(sklearn.preprocessing.data.normalize): None
# Failed to apply transform(sklearn.preprocessing.data.normalize): <class 'synthesis.runtime_helpers.ColumnLoop'>
#
# 100%|██████████| 10/10 [00:07<00:00,  1.33it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# [Transforms] Pruning programs of depth 2
# Generating modeling
# Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 50.99it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 42.31it/s]
#   3%|▎         | 1/31 [00:00<00:12,  2.45it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   3%|▎         | 1/32 [00:00<00:10,  2.96it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:01, 13.75it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.80it/s]
#   6%|▋         | 2/31 [00:01<00:16,  1.78it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   3%|▎         | 1/32 [00:00<00:10,  2.84it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:01, 13.56it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.53it/s]
#  10%|▉         | 3/31 [00:01<00:17,  1.61it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 58.19it/s]Failed to apply model: xgboost.core.Booster
#
#  13%|█▎        | 4/31 [00:02<00:15,  1.71it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 52.26it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.86it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  16%|█▌        | 5/31 [00:03<00:15,  1.65it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 51.59it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.55it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  19%|█▉        | 6/31 [00:03<00:15,  1.60it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  22%|██▏       | 7/32 [00:00<00:00, 38.77it/s]Failed to apply model: xgboost.core.Booster
#
#  28%|██▊       | 9/32 [00:00<00:00, 30.81it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  23%|██▎       | 7/31 [00:04<00:15,  1.54it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 34.84it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.11it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  26%|██▌       | 8/31 [00:05<00:15,  1.53it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
# Failed computing missing
# Failed to apply model: builtins.module
#
#  16%|█▌        | 5/32 [00:00<00:01, 25.29it/s]
#  28%|██▊       | 9/32 [00:00<00:01, 19.96it/s]
#  29%|██▉       | 9/31 [00:05<00:14,  1.56it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 36.10it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.89it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  32%|███▏      | 10/31 [00:06<00:13,  1.54it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 35.44it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.21it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  35%|███▌      | 11/31 [00:07<00:13,  1.53it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 51.91it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 32.09it/s]
#  39%|███▊      | 12/31 [00:07<00:11,  1.58it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 52.21it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.95it/s]
#  42%|████▏     | 13/31 [00:07<00:11,  1.63it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 50.70it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.46it/s]
#  45%|████▌     | 14/31 [00:08<00:10,  1.68it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 51.71it/s]Failed to apply model: builtins.module
# Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:00, 31.64it/s]
#  48%|████▊     | 15/31 [00:08<00:09,  1.72it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:03,  8.10it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 13.63it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.62it/s]
#  52%|█████▏    | 16/31 [00:09<00:08,  1.69it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:03,  8.08it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 13.63it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.63it/s]
#  55%|█████▍    | 17/31 [00:10<00:08,  1.67it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:03,  8.35it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 13.91it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.85it/s]
#  58%|█████▊    | 18/31 [00:10<00:07,  1.65it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#   9%|▉         | 3/32 [00:00<00:03,  8.13it/s]
#  22%|██▏       | 7/32 [00:00<00:01, 13.70it/s]Failed to apply model: xgboost.core.Booster
#
#  31%|███▏      | 10/32 [00:00<00:01, 15.73it/s]
#  61%|██████▏   | 19/31 [00:11<00:07,  1.64it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 49.20it/s]Failed to apply model: xgboost.core.Booster
#
#  65%|██████▍   | 20/31 [00:11<00:06,  1.68it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 48.49it/s]Failed to apply model: xgboost.core.Booster
#
#  68%|██████▊   | 21/31 [00:12<00:05,  1.72it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 25.43it/s]Failed to apply model: xgboost.core.Booster
#
#  71%|███████   | 22/31 [00:12<00:05,  1.74it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 49.52it/s]Failed to apply model: xgboost.core.Booster
#
#  74%|███████▍  | 23/31 [00:12<00:04,  1.77it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 49.09it/s]Failed to apply model: xgboost.core.Booster
#
#  77%|███████▋  | 24/31 [00:13<00:03,  1.81it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  22%|██▏       | 7/32 [00:00<00:00, 50.38it/s]Failed to apply model: xgboost.core.Booster
#
#  81%|████████  | 25/31 [00:13<00:03,  1.84it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 33.55it/s]Failed to apply model: xgboost.core.Booster
#
#  84%|████████▍ | 26/31 [00:13<00:02,  1.87it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 34.10it/s]Failed to apply model: xgboost.core.Booster
#
#  87%|████████▋ | 27/31 [00:14<00:02,  1.90it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 34.81it/s]Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:00, 28.30it/s]
#  90%|█████████ | 28/31 [00:14<00:01,  1.92it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 54.67it/s]Failed to apply model: xgboost.core.Booster
#
#  28%|██▊       | 9/32 [00:00<00:00, 29.13it/s]
#  94%|█████████▎| 29/31 [00:14<00:01,  1.93it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#  19%|█▉        | 6/32 [00:00<00:00, 34.24it/s]Failed to apply model: xgboost.core.Booster
#
#  25%|██▌       | 8/32 [00:00<00:00, 27.82it/s]
#  97%|█████████▋| 30/31 [00:15<00:00,  1.95it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]Failed to apply model: builtins.module
#
#  19%|█▉        | 6/32 [00:00<00:00, 56.93it/s]Failed to apply model: xgboost.core.Booster
#
#  28%|██▊       | 9/32 [00:00<00:00, 29.42it/s]
# 100%|██████████| 31/31 [00:15<00:00,  1.97it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# [Model] Pruning programs of depth 0
# [Model] Pruning programs of depth 1
# [Model] Pruning programs of depth 2
# [Model] Pruning programs of depth 3
# Adding test data
# Failed to add test data, program depth: 0
#  35%|███▌      | 14/40 [00:00<00:00, 62.81it/s]Failed to add test data, program depth: 1
# Failed to add test data, program depth: 1
#  70%|███████   | 28/40 [00:00<00:00, 49.27it/s]Failed to add test data, program depth: 3
# Failed to add test data, program depth: 3
# 100%|██████████| 40/40 [00:00<00:00, 41.00it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   0%|          | 0/35 [00:00<?, ?it/s]
#   9%|▊         | 3/35 [00:00<00:01, 28.64it/s]
#  11%|█▏        | 4/35 [00:00<00:02, 12.29it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  14%|█▍        | 5/35 [00:00<00:04,  6.83it/s]/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/neural_network/multilayer_perceptron.py:563: ConvergenceWarning: Stochastic Optimizer: Maximum iterations reached and the optimization hasn't converged yet.
#   % (), ConvergenceWarning)
#
#  17%|█▋        | 6/35 [00:01<00:05,  5.24it/s]
#  26%|██▌       | 9/35 [00:01<00:03,  7.02it/s]
#  34%|███▍      | 12/35 [00:01<00:02,  8.65it/s]
#  40%|████      | 14/35 [00:01<00:02,  9.40it/s]
#  49%|████▊     | 17/35 [00:01<00:01, 10.46it/s]
#  54%|█████▍    | 19/35 [00:01<00:01, 10.96it/s]
#  60%|██████    | 21/35 [00:01<00:01, 11.28it/s]
#  66%|██████▌   | 23/35 [00:02<00:01, 11.50it/s]
#  74%|███████▍  | 26/35 [00:02<00:00, 12.11it/s]
#  80%|████████  | 28/35 [00:02<00:00, 12.44it/s]
#  86%|████████▌ | 30/35 [00:02<00:00, 12.57it/s]
#  91%|█████████▏| 32/35 [00:02<00:00, 12.76it/s]
#  97%|█████████▋| 34/35 [00:02<00:00, 12.96it/s]
# 100%|██████████| 35/35 [00:02<00:00, 12.46it/s]

# %%
print(m)
# Out:
# <al.AL object at 0x7fb73b23aa90>

# %%
print(progs[0].pipeline_code())
print('\n\n-----------------------\n')
print(progs[1].pipeline_code())
print('\n\n-----------------------\n')
print(progs[3].pipeline_code())
print('\n\n-----------------------\n')
print(progs[4].pipeline_code())
# Out:
# import xgboost
# import sklearn
# import sklearn.ensemble.forest
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('model', sklearn.ensemble.forest.ExtraTreesClassifier())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)
#
#
# -----------------------
#
# import xgboost
# import sklearn
# import sklearn.naive_bayes
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('model', sklearn.naive_bayes.GaussianNB())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)
#
#
# -----------------------
#
# import xgboost
# import sklearn
# import sklearn.ensemble.gradient_boosting
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('model', sklearn.ensemble.gradient_boosting.GradientBoostingClassifier())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)
#
#
# -----------------------
#
# import xgboost
# import sklearn.preprocessing.data
# import sklearn
# import sklearn.neural_network.multilayer_perceptron
#
# from sklearn.pipeline import Pipeline
# p = Pipeline([('t0', sklearn.preprocessing.data.StandardScaler()),('model', sklearn.neural_network.multilayer_perceptron.MLPClassifier())])
# p.fit(X_train, y_train)
# print(p.score(X_val, y_val))
# p.fit(X, y)
# def predict(X_test): return p.predict(X_test)

# %%
import synthesis.runtime_helpers as runtime_helpers
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

# %%
import xgboost
import sklearn.preprocessing.data
import sklearn.preprocessing.imputation
import sklearn
import sklearn.svm.classes

from sklearn.pipeline import Pipeline
p = Pipeline([('t0', runtime_helpers.ColumnLoop(sklearn.preprocessing.data.StandardScaler)),('t1', sklearn.preprocessing.imputation.Imputer()),('model', sklearn.svm.classes.LinearSVC())])
p.fit(X_train, y_train)
print(p.score(X_val, y_val))
p.fit(X, y)
def predict(X_test): return p.predict(X_test)
# Out:
# 0.91
